# %% [markdown]
# Interrogate the impact of the COVID lockdown in the economy.

# %%
from datetime import date
import pandas as pd

from src.data.download_stock import download_stocks
from src.data.preprocessing import cacl_monthly_avg_kpi
from src.models.causal_impact import causal_impact_analysis
from src.utils.plots import timeline_px
from src.utils.variables import pharma_companies, consumer_staples, retail, global_economy_indicators

# %%
industry_tickers = {"Pharma" : pharma_companies,
                    "Consumables" : consumer_staples,
                    "Retail" : retail,
                    "Global Economy" : global_economy_indicators}

tickers = (list(pharma_companies.keys())
          + list(consumer_staples.keys())
          + list(retail.keys())
          + list(global_economy_indicators.keys()))

# %%
raw_dir = "./data/raw/"
start_date = date(2017, 1, 1)
end_date = date(2020, 12, 30)
event_date = date(2020, 3, 1) # Covid lockdown

# %% [markdown]
# Download stock market data from yahoo finance

# %%
# # Download stock market data
# download_stocks(start_date, end_date, tickers, raw_dir)

# %%
kpi= "Adj Close"

monthly_abj_close = pd.DataFrame()
for ticker in tickers:
    ticker_df = pd.read_csv(f"{raw_dir}{ticker}.csv", index_col=0)
    ticker_df.index = pd.to_datetime(ticker_df.index)
    ticker_df  = cacl_monthly_avg_kpi(ticker_df, kpi)
    ticker_df.name = ticker
    
    monthly_abj_close = pd.concat([monthly_abj_close, ticker_df], axis=1)

# %% [markdown]
# Plot timeline highlighting the start date of the first Covid lockdown, March 2020

# %%
event_str = event_date.strftime(format="%Y-%m")
labels = {"variable":"", "value":kpi, "index":"Month"}

for name, tickers_dict in industry_tickers.items():
    tickers = list(tickers_dict.keys())
    df = monthly_abj_close[tickers]
    write_html =  f"./figures/{name.lower()}.html"
    write_image = f"./figures/{name.lower()}.png"
    timeline_px(df, event_str, name, None, write_image, labels)

# %%
def covid_causal_impact(tickers_dict:dict):
    pre_period = [start_date, date(event_date.year, event_date.month-1, 1)]
    pre_period = [pd.to_datetime(x) for x in pre_period]
    post_period = [event_date, date(end_date.year, end_date.month-1, 1)]
    post_period = [pd.to_datetime(x) for x in post_period]

    for company in tickers_dict.keys():
        print(f"===== {tickers_dict[company]} =====")
        tickers = [company,]
        tickers += list(global_economy_indicators.keys())
        
        df = monthly_abj_close[tickers]
        df.dropna(axis=1, inplace=True)
        ci = causal_impact_analysis(df, company, pre_period, post_period)
        
        ci.summary(output="summary", path=f"./figures/python/{company}.summary.txt")
        ci.summary(output="report", path=f"./figures/python/{company}.report.txt") 
            
        ci.plot(panels=['original', 'pointwise', 'cumulative'], figsize=(15,5), 
                fname=f"./figures/python/{company}.png")

# %%
covid_causal_impact(pharma_companies)
# Out:
# ===== Pfizer Inc. =====
# C:\Users\joanp\AppData\Local\Temp\ipykernel_39932\4049619924.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\joanp\anaconda3\envs\causal_inference_ts\Lib\site-packages\statsmodels\tsa\statespace\representation.py:374: FutureWarning:
#
# Unknown keyword arguments: dict_keys(['alpha']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
# The mean absolute percentage error in the pre period is 0.03%
#                                Average      Cumulative
# Actual                              30             270
# Predicted                           23             208
# 95% CI                        [18, 27]      [168, 248]
#
# Absolute Effect                      6              62
# 95% CI                         [11, 2]       [102, 22]
#
# Relative Effect                  30.0%           30.0%
# 95% CI                  [49.1%, 10.8%]  [49.1%, 10.8%]
#
# P-value                           0.0%
# Prob. of Causal Effect          100.0%
# None
#                                Average      Cumulative
# Actual                              30             270
# Predicted                           23             208
# 95% CI                        [18, 27]      [168, 248]
#
# Absolute Effect                      6              62
# 95% CI                         [11, 2]       [102, 22]
#
# Relative Effect                  30.0%           30.0%
# 95% CI                  [49.1%, 10.8%]  [49.1%, 10.8%]
#
# P-value                           0.0%
# Prob. of Causal Effect          100.0%
# During the post-intervention period, the response             variable had an average value of             approx. 30.
# By contrast, in  the absence of an intervention, we would have expected an average response of 23. The 95% interval of
# this counterfactual prediction is [18, 27]. Subtracting this prediction from the observed response yields an estimate of
# the causal effect the intervention had on the response variable. This effect is 6 with a 95% interval of [11, 2]. For a
# discussion of the significance of this effect, see below.
#
#
#  Summing up the individual data points during the post-intervention period (which can only sometimes be meaningfully
# interpreted), the response variable had an overall value of 270.  By contrast, had  the intervention not taken place, we
# would have expected a sum of 208. The 95% interval of this prediction is [168, 248]
#
#
#  The above results are given in terms of absolute numbers. In relative terms, the response variable showed  an increase
# of  30.0%. The 95% interval of this percentage is [49.1%, 10.8%]
#
#
#  This means that the positive effect observed during the intervention period is statistically significant and unlikely
# to be due to random fluctuations. It should be noted, however, that the question of whether this increase also bears
# substantive significance can only be answered by comparing the absolute effect 6 to the original goal of the underlying
# intervention.
#
#
# The probability of obtaining this effect by                 chance is very small (Bayesian one-sided tail-area
# probability 0.0). This means the                 causal effect can be considered statistically
# significant.
# ===== Johnson & Johnson =====
# The mean absolute percentage error in the pre period is 0.02%
#                               Average     Cumulative
# Actual                            131           1186
# Predicted                         111           1005
# 95% CI                      [98, 125]    [884, 1125]
#
# Absolute Effect                    20            181
# 95% CI                        [33, 6]      [301, 60]
#
# Relative Effect                 18.0%          18.0%
# 95% CI                  [30.0%, 6.1%]  [30.0%, 6.1%]
#
# P-value                          0.0%
# Prob. of Causal Effect         100.0%
# None
#                               Average     Cumulative
# Actual                            131           1186
# Predicted                         111           1005
# 95% CI                      [98, 125]    [884, 1125]
#
# Absolute Effect                    20            181
# 95% CI                        [33, 6]      [301, 60]
#
# Relative Effect                 18.0%          18.0%
# 95% CI                  [30.0%, 6.1%]  [30.0%, 6.1%]
#
# P-value                          0.0%
# Prob. of Causal Effect         100.0%
# During the post-intervention period, the response             variable had an average value of             approx. 131.
# By contrast, in  the absence of an intervention, we would have expected an average response of 111. The 95% interval of
# this counterfactual prediction is [98, 125]. Subtracting this prediction from the observed response yields an estimate
# of the causal effect the intervention had on the response variable. This effect is 20 with a 95% interval of [33, 6].
# For a discussion of the significance of this effect, see below.
#
#
#  Summing up the individual data points during the post-intervention period (which can only sometimes be meaningfully
# interpreted), the response variable had an overall value of 1186.  By contrast, had  the intervention not taken place,
# we would have expected a sum of 1005. The 95% interval of this prediction is [884, 1125]
#
#
#  The above results are given in terms of absolute numbers. In relative terms, the response variable showed  an increase
# of  18.0%. The 95% interval of this percentage is [30.0%, 6.1%]
#
#
#  This means that the positive effect observed during the intervention period is statistically significant and unlikely
# to be due to random fluctuations. It should be noted, however, that the question of whether this increase also bears
# substantive significance can only be answered by comparing the absolute effect 20 to the original goal of the underlying
# intervention.
#
#
# The probability of obtaining this effect by                 chance is very small (Bayesian one-sided tail-area
# probability 0.0). This means the                 causal effect can be considered statistically
# significant.
# C:\Users\joanp\AppData\Local\Temp\ipykernel_39932\4049619924.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\joanp\anaconda3\envs\causal_inference_ts\Lib\site-packages\statsmodels\tsa\statespace\representation.py:374: FutureWarning:
#
# Unknown keyword arguments: dict_keys(['alpha']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
# ===== Novartis AG =====
# The mean absolute percentage error in the pre period is 0.02%
#                                Average      Cumulative
# Actual                              75             680
# Predicted                           71             642
# 95% CI                        [64, 78]      [576, 708]
#
# Absolute Effect                      4              37
# 95% CI                        [11, -3]      [103, -28]
#
# Relative Effect                   5.9%            5.9%
# 95% CI                  [16.2%, -4.4%]  [16.2%, -4.4%]
#
# P-value                           0.0%
# Prob. of Causal Effect          100.0%
# None
#                                Average      Cumulative
# Actual                              75             680
# Predicted                           71             642
# 95% CI                        [64, 78]      [576, 708]
#
# Absolute Effect                      4              37
# 95% CI                        [11, -3]      [103, -28]
#
# Relative Effect                   5.9%            5.9%
# 95% CI                  [16.2%, -4.4%]  [16.2%, -4.4%]
#
# P-value                           0.0%
# Prob. of Causal Effect          100.0%
# During the post-intervention period, the response             variable had an average value of             approx. 75.
# By contrast, in  the absence of an intervention, we would have expected an average response of 71. The 95% interval of
# this counterfactual prediction is [64, 78]. Subtracting this prediction from the observed response yields an estimate of
# the causal effect the intervention had on the response variable. This effect is 4 with a 95% interval of [11, -3]. For a
# discussion of the significance of this effect, see below.
#
#
#  Summing up the individual data points during the post-intervention period (which can only sometimes be meaningfully
# interpreted), the response variable had an overall value of 680.  By contrast, had  the intervention not taken place, we
# would have expected a sum of 642. The 95% interval of this prediction is [576, 708]
#
#
#  The above results are given in terms of absolute numbers. In relative terms, the response variable showed  an increase
# of  5.9%. The 95% interval of this percentage is [16.2%, -4.4%]
#
#
#  This means that the positive effect observed during the intervention period is statistically significant and unlikely
# to be due to random fluctuations. It should be noted, however, that the question of whether this increase also bears
# substantive significance can only be answered by comparing the absolute effect 4 to the original goal of the underlying
# intervention.
#
#
# The probability of obtaining this effect by                 chance is very small (Bayesian one-sided tail-area
# probability 0.0). This means the                 causal effect can be considered statistically
# significant.
# C:\Users\joanp\AppData\Local\Temp\ipykernel_39932\4049619924.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\joanp\anaconda3\envs\causal_inference_ts\Lib\site-packages\statsmodels\tsa\statespace\representation.py:374: FutureWarning:
#
# Unknown keyword arguments: dict_keys(['alpha']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
# ===== Roche Holding AG =====
# The mean absolute percentage error in the pre period is 0.05%
#                                Average      Cumulative
# Actual                             112            1015
# Predicted                           85             767
# 95% CI                       [49, 121]     [443, 1091]
#
# Absolute Effect                     27             248
# 95% CI                        [63, -8]      [572, -75]
#
# Relative Effect                  32.3%           32.3%
# 95% CI                  [74.6%, -9.9%]  [74.6%, -9.9%]
#
# P-value                           0.0%
# Prob. of Causal Effect          100.0%
# None
#                                Average      Cumulative
# Actual                             112            1015
# Predicted                           85             767
# 95% CI                       [49, 121]     [443, 1091]
#
# Absolute Effect                     27             248
# 95% CI                        [63, -8]      [572, -75]
#
# Relative Effect                  32.3%           32.3%
# 95% CI                  [74.6%, -9.9%]  [74.6%, -9.9%]
#
# P-value                           0.0%
# Prob. of Causal Effect          100.0%
# During the post-intervention period, the response             variable had an average value of             approx. 112.
# By contrast, in  the absence of an intervention, we would have expected an average response of 85. The 95% interval of
# this counterfactual prediction is [49, 121]. Subtracting this prediction from the observed response yields an estimate
# of the causal effect the intervention had on the response variable. This effect is 27 with a 95% interval of [63, -8].
# For a discussion of the significance of this effect, see below.
#
#
#  Summing up the individual data points during the post-intervention period (which can only sometimes be meaningfully
# interpreted), the response variable had an overall value of 1015.  By contrast, had  the intervention not taken place,
# we would have expected a sum of 767. The 95% interval of this prediction is [443, 1091]
#
#
#  The above results are given in terms of absolute numbers. In relative terms, the response variable showed  an increase
# of  32.3%. The 95% interval of this percentage is [74.6%, -9.9%]
#
#
#  This means that the positive effect observed during the intervention period is statistically significant and unlikely
# to be due to random fluctuations. It should be noted, however, that the question of whether this increase also bears
# substantive significance can only be answered by comparing the absolute effect 27 to the original goal of the underlying
# intervention.
#
#
# The probability of obtaining this effect by                 chance is very small (Bayesian one-sided tail-area
# probability 0.0). This means the                 causal effect can be considered statistically
# significant.
# C:\Users\joanp\AppData\Local\Temp\ipykernel_39932\4049619924.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\joanp\anaconda3\envs\causal_inference_ts\Lib\site-packages\statsmodels\tsa\statespace\representation.py:374: FutureWarning:
#
# Unknown keyword arguments: dict_keys(['alpha']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
# ===== Merck & Co., Inc. =====
# The mean absolute percentage error in the pre period is 0.04%
#                                Average      Cumulative
# Actual                              68             612
# Predicted                           53             484
# 95% CI                        [45, 62]      [406, 561]
#
# Absolute Effect                     14             128
# 95% CI                         [22, 5]       [206, 51]
#
# Relative Effect                  26.6%           26.6%
# 95% CI                  [42.6%, 10.7%]  [42.6%, 10.7%]
#
# P-value                           0.0%
# Prob. of Causal Effect          100.0%
# None
#                                Average      Cumulative
# Actual                              68             612
# Predicted                           53             484
# 95% CI                        [45, 62]      [406, 561]
#
# Absolute Effect                     14             128
# 95% CI                         [22, 5]       [206, 51]
#
# Relative Effect                  26.6%           26.6%
# 95% CI                  [42.6%, 10.7%]  [42.6%, 10.7%]
#
# P-value                           0.0%
# Prob. of Causal Effect          100.0%
# During the post-intervention period, the response             variable had an average value of             approx. 68.
# By contrast, in  the absence of an intervention, we would have expected an average response of 53. The 95% interval of
# this counterfactual prediction is [45, 62]. Subtracting this prediction from the observed response yields an estimate of
# the causal effect the intervention had on the response variable. This effect is 14 with a 95% interval of [22, 5]. For a
# discussion of the significance of this effect, see below.
#
#
#  Summing up the individual data points during the post-intervention period (which can only sometimes be meaningfully
# interpreted), the response variable had an overall value of 612.  By contrast, had  the intervention not taken place, we
# would have expected a sum of 484. The 95% interval of this prediction is [406, 561]
#
#
#  The above results are given in terms of absolute numbers. In relative terms, the response variable showed  an increase
# of  26.6%. The 95% interval of this percentage is [42.6%, 10.7%]
#
#
#  This means that the positive effect observed during the intervention period is statistically significant and unlikely
# to be due to random fluctuations. It should be noted, however, that the question of whether this increase also bears
# substantive significance can only be answered by comparing the absolute effect 14 to the original goal of the underlying
# intervention.
#
#
# The probability of obtaining this effect by                 chance is very small (Bayesian one-sided tail-area
# probability 0.0). This means the                 causal effect can be considered statistically
# significant.
# C:\Users\joanp\AppData\Local\Temp\ipykernel_39932\4049619924.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\joanp\anaconda3\envs\causal_inference_ts\Lib\site-packages\statsmodels\tsa\statespace\representation.py:374: FutureWarning:
#
# Unknown keyword arguments: dict_keys(['alpha']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
# ===== Sanofi =====
# The mean absolute percentage error in the pre period is 0.03%
#                               Average     Cumulative
# Actual                             43            393
# Predicted                          37            336
# 95% CI                       [32, 42]     [292, 380]
#
# Absolute Effect                     6             56
# 95% CI                        [11, 1]      [101, 12]
#
# Relative Effect                 16.9%          16.9%
# 95% CI                  [30.0%, 3.8%]  [30.0%, 3.8%]
#
# P-value                          0.0%
# Prob. of Causal Effect         100.0%
# None
#                               Average     Cumulative
# Actual                             43            393
# Predicted                          37            336
# 95% CI                       [32, 42]     [292, 380]
#
# Absolute Effect                     6             56
# 95% CI                        [11, 1]      [101, 12]
#
# Relative Effect                 16.9%          16.9%
# 95% CI                  [30.0%, 3.8%]  [30.0%, 3.8%]
#
# P-value                          0.0%
# Prob. of Causal Effect         100.0%
# During the post-intervention period, the response             variable had an average value of             approx. 43.
# By contrast, in  the absence of an intervention, we would have expected an average response of 37. The 95% interval of
# this counterfactual prediction is [32, 42]. Subtracting this prediction from the observed response yields an estimate of
# the causal effect the intervention had on the response variable. This effect is 6 with a 95% interval of [11, 1]. For a
# discussion of the significance of this effect, see below.
#
#
#  Summing up the individual data points during the post-intervention period (which can only sometimes be meaningfully
# interpreted), the response variable had an overall value of 393.  By contrast, had  the intervention not taken place, we
# would have expected a sum of 336. The 95% interval of this prediction is [292, 380]
#
#
#  The above results are given in terms of absolute numbers. In relative terms, the response variable showed  an increase
# of  16.9%. The 95% interval of this percentage is [30.0%, 3.8%]
#
#
#  This means that the positive effect observed during the intervention period is statistically significant and unlikely
# to be due to random fluctuations. It should be noted, however, that the question of whether this increase also bears
# substantive significance can only be answered by comparing the absolute effect 6 to the original goal of the underlying
# intervention.
#
#
# The probability of obtaining this effect by                 chance is very small (Bayesian one-sided tail-area
# probability 0.0). This means the                 causal effect can be considered statistically
# significant.
# C:\Users\joanp\AppData\Local\Temp\ipykernel_39932\4049619924.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\joanp\anaconda3\envs\causal_inference_ts\Lib\site-packages\statsmodels\tsa\statespace\representation.py:374: FutureWarning:
#
# Unknown keyword arguments: dict_keys(['alpha']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
# ===== GlaxoSmithKline plc =====
# The mean absolute percentage error in the pre period is 0.03%
#                               Average     Cumulative
# Actual                             33            301
# Predicted                          29            263
# 95% CI                       [25, 33]     [229, 298]
#
# Absolute Effect                     4             37
# 95% CI                         [8, 0]        [72, 3]
#
# Relative Effect                 14.4%          14.4%
# 95% CI                  [27.5%, 1.2%]  [27.5%, 1.2%]
#
# P-value                          0.0%
# Prob. of Causal Effect         100.0%
# None
#                               Average     Cumulative
# Actual                             33            301
# Predicted                          29            263
# 95% CI                       [25, 33]     [229, 298]
#
# Absolute Effect                     4             37
# 95% CI                         [8, 0]        [72, 3]
#
# Relative Effect                 14.4%          14.4%
# 95% CI                  [27.5%, 1.2%]  [27.5%, 1.2%]
#
# P-value                          0.0%
# Prob. of Causal Effect         100.0%
# During the post-intervention period, the response             variable had an average value of             approx. 33.
# By contrast, in  the absence of an intervention, we would have expected an average response of 29. The 95% interval of
# this counterfactual prediction is [25, 33]. Subtracting this prediction from the observed response yields an estimate of
# the causal effect the intervention had on the response variable. This effect is 4 with a 95% interval of [8, 0]. For a
# discussion of the significance of this effect, see below.
#
#
#  Summing up the individual data points during the post-intervention period (which can only sometimes be meaningfully
# interpreted), the response variable had an overall value of 301.  By contrast, had  the intervention not taken place, we
# would have expected a sum of 263. The 95% interval of this prediction is [229, 298]
#
#
#  The above results are given in terms of absolute numbers. In relative terms, the response variable showed  an increase
# of  14.4%. The 95% interval of this percentage is [27.5%, 1.2%]
#
#
#  This means that the positive effect observed during the intervention period is statistically significant and unlikely
# to be due to random fluctuations. It should be noted, however, that the question of whether this increase also bears
# substantive significance can only be answered by comparing the absolute effect 4 to the original goal of the underlying
# intervention.
#
#
# The probability of obtaining this effect by                 chance is very small (Bayesian one-sided tail-area
# probability 0.0). This means the                 causal effect can be considered statistically
# significant.
# C:\Users\joanp\AppData\Local\Temp\ipykernel_39932\4049619924.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\joanp\anaconda3\envs\causal_inference_ts\Lib\site-packages\statsmodels\tsa\statespace\representation.py:374: FutureWarning:
#
# Unknown keyword arguments: dict_keys(['alpha']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
# ===== AstraZeneca PLC =====
# The mean absolute percentage error in the pre period is 0.05%
#                               Average     Cumulative
# Actual                             48            437
# Predicted                          40            361
# 95% CI                       [34, 46]     [306, 416]
#
# Absolute Effect                     8             76
# 95% CI                        [14, 2]      [130, 21]
#
# Relative Effect                 21.1%          21.1%
# 95% CI                  [36.2%, 5.9%]  [36.2%, 5.9%]
#
# P-value                          0.0%
# Prob. of Causal Effect         100.0%
# None
#                               Average     Cumulative
# Actual                             48            437
# Predicted                          40            361
# 95% CI                       [34, 46]     [306, 416]
#
# Absolute Effect                     8             76
# 95% CI                        [14, 2]      [130, 21]
#
# Relative Effect                 21.1%          21.1%
# 95% CI                  [36.2%, 5.9%]  [36.2%, 5.9%]
#
# P-value                          0.0%
# Prob. of Causal Effect         100.0%
# During the post-intervention period, the response             variable had an average value of             approx. 48.
# By contrast, in  the absence of an intervention, we would have expected an average response of 40. The 95% interval of
# this counterfactual prediction is [34, 46]. Subtracting this prediction from the observed response yields an estimate of
# the causal effect the intervention had on the response variable. This effect is 8 with a 95% interval of [14, 2]. For a
# discussion of the significance of this effect, see below.
#
#
#  Summing up the individual data points during the post-intervention period (which can only sometimes be meaningfully
# interpreted), the response variable had an overall value of 437.  By contrast, had  the intervention not taken place, we
# would have expected a sum of 361. The 95% interval of this prediction is [306, 416]
#
#
#  The above results are given in terms of absolute numbers. In relative terms, the response variable showed  an increase
# of  21.1%. The 95% interval of this percentage is [36.2%, 5.9%]
#
#
#  This means that the positive effect observed during the intervention period is statistically significant and unlikely
# to be due to random fluctuations. It should be noted, however, that the question of whether this increase also bears
# substantive significance can only be answered by comparing the absolute effect 8 to the original goal of the underlying
# intervention.
#
#
# The probability of obtaining this effect by                 chance is very small (Bayesian one-sided tail-area
# probability 0.0). This means the                 causal effect can be considered statistically
# significant.
# C:\Users\joanp\AppData\Local\Temp\ipykernel_39932\4049619924.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\joanp\anaconda3\envs\causal_inference_ts\Lib\site-packages\statsmodels\tsa\statespace\representation.py:374: FutureWarning:
#
# Unknown keyword arguments: dict_keys(['alpha']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
# ===== Eli Lilly and Company =====
# The mean absolute percentage error in the pre period is 0.04%
#                                Average      Cumulative
# Actual                             142            1282
# Predicted                          130            1173
# 95% CI                      [112, 147]    [1016, 1330]
#
# Absolute Effect                     12             109
# 95% CI                        [29, -5]      [266, -47]
#
# Relative Effect                   9.3%            9.3%
# 95% CI                  [22.7%, -4.1%]  [22.7%, -4.1%]
#
# P-value                           0.0%
# Prob. of Causal Effect          100.0%
# None
#                                Average      Cumulative
# Actual                             142            1282
# Predicted                          130            1173
# 95% CI                      [112, 147]    [1016, 1330]
#
# Absolute Effect                     12             109
# 95% CI                        [29, -5]      [266, -47]
#
# Relative Effect                   9.3%            9.3%
# 95% CI                  [22.7%, -4.1%]  [22.7%, -4.1%]
#
# P-value                           0.0%
# Prob. of Causal Effect          100.0%
# During the post-intervention period, the response             variable had an average value of             approx. 142.
# By contrast, in  the absence of an intervention, we would have expected an average response of 130. The 95% interval of
# this counterfactual prediction is [112, 147]. Subtracting this prediction from the observed response yields an estimate
# of the causal effect the intervention had on the response variable. This effect is 12 with a 95% interval of [29, -5].
# For a discussion of the significance of this effect, see below.
#
#
#  Summing up the individual data points during the post-intervention period (which can only sometimes be meaningfully
# interpreted), the response variable had an overall value of 1282.  By contrast, had  the intervention not taken place,
# we would have expected a sum of 1173. The 95% interval of this prediction is [1016, 1330]
#
#
#  The above results are given in terms of absolute numbers. In relative terms, the response variable showed  an increase
# of  9.3%. The 95% interval of this percentage is [22.7%, -4.1%]
#
#
#  This means that the positive effect observed during the intervention period is statistically significant and unlikely
# to be due to random fluctuations. It should be noted, however, that the question of whether this increase also bears
# substantive significance can only be answered by comparing the absolute effect 12 to the original goal of the underlying
# intervention.
#
#
# The probability of obtaining this effect by                 chance is very small (Bayesian one-sided tail-area
# probability 0.0). This means the                 causal effect can be considered statistically
# significant.
# C:\Users\joanp\AppData\Local\Temp\ipykernel_39932\4049619924.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\joanp\anaconda3\envs\causal_inference_ts\Lib\site-packages\statsmodels\tsa\statespace\representation.py:374: FutureWarning:
#
# Unknown keyword arguments: dict_keys(['alpha']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
# ===== AbbVie Inc. =====
# The mean absolute percentage error in the pre period is 0.05%
#                                Average      Cumulative
# Actual                              77             700
# Predicted                           89             808
# 95% CI                       [72, 107]      [651, 965]
#
# Absolute Effect                    -12            -108
# 95% CI                        [5, -29]      [48, -265]
#
# Relative Effect                 -13.4%          -13.4%
# 95% CI                  [6.0%, -32.9%]  [6.0%, -32.9%]
#
# P-value                           0.0%
# Prob. of Causal Effect          100.0%
# None
#                                Average      Cumulative
# Actual                              77             700
# Predicted                           89             808
# 95% CI                       [72, 107]      [651, 965]
#
# Absolute Effect                    -12            -108
# 95% CI                        [5, -29]      [48, -265]
#
# Relative Effect                 -13.4%          -13.4%
# 95% CI                  [6.0%, -32.9%]  [6.0%, -32.9%]
#
# P-value                           0.0%
# Prob. of Causal Effect          100.0%
# During the post-intervention period, the response             variable had an average value of             approx. 77.
# By contrast, in  the absence of an intervention, we would have expected an average response of 89. The 95% interval of
# this counterfactual prediction is [72, 107]. Subtracting this prediction from the observed response yields an estimate
# of the causal effect the intervention had on the response variable. This effect is -12 with a 95% interval of [5, -29].
# For a discussion of the significance of this effect, see below.
#
#
#  Summing up the individual data points during the post-intervention period (which can only sometimes be meaningfully
# interpreted), the response variable had an overall value of 700.  By contrast, had  the intervention not taken place, we
# would have expected a sum of 808. The 95% interval of this prediction is [651, 965]
#
#
#  The above results are given in terms of absolute numbers. In relative terms, the response variable showed  a decrease
# of  -13.4%. The 95% interval of this percentage is [6.0%, -32.9%]
#
#
#  This  means that the negative effect observed during the intervention period is statistically significant. If the
# experimenter had expected a positive effect, it is recommended to double-check whether anomalies in the control
# variables may have caused an overly optimistic expectation of what should have happened in the response variable in the
# absence of the intervention.
#
#
# The probability of obtaining this effect by                 chance is very small (Bayesian one-sided tail-area
# probability 0.0). This means the                 causal effect can be considered statistically
# significant.
# C:\Users\joanp\AppData\Local\Temp\ipykernel_39932\4049619924.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\joanp\anaconda3\envs\causal_inference_ts\Lib\site-packages\statsmodels\tsa\statespace\representation.py:374: FutureWarning:
#
# Unknown keyword arguments: dict_keys(['alpha']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.

# %%
covid_causal_impact(retail)
# Out:
# ===== Amazon.com, Inc. =====
# The mean absolute percentage error in the pre period is 0.03%
#                                Average      Cumulative
# Actual                             138            1247
# Predicted                          135            1216
# 95% CI                      [124, 146]    [1118, 1314]
#
# Absolute Effect                      3              30
# 95% CI                        [14, -7]      [128, -66]
#
# Relative Effect                   2.5%            2.5%
# 95% CI                  [10.6%, -5.5%]  [10.6%, -5.5%]
#
# P-value                           0.0%
# Prob. of Causal Effect          100.0%
# None
#                                Average      Cumulative
# Actual                             138            1247
# Predicted                          135            1216
# 95% CI                      [124, 146]    [1118, 1314]
#
# Absolute Effect                      3              30
# 95% CI                        [14, -7]      [128, -66]
#
# Relative Effect                   2.5%            2.5%
# 95% CI                  [10.6%, -5.5%]  [10.6%, -5.5%]
#
# P-value                           0.0%
# Prob. of Causal Effect          100.0%
# During the post-intervention period, the response             variable had an average value of             approx. 138.
# By contrast, in  the absence of an intervention, we would have expected an average response of 135. The 95% interval of
# this counterfactual prediction is [124, 146]. Subtracting this prediction from the observed response yields an estimate
# of the causal effect the intervention had on the response variable. This effect is 3 with a 95% interval of [14, -7].
# For a discussion of the significance of this effect, see below.
#
#
#  Summing up the individual data points during the post-intervention period (which can only sometimes be meaningfully
# interpreted), the response variable had an overall value of 1247.  By contrast, had  the intervention not taken place,
# we would have expected a sum of 1216. The 95% interval of this prediction is [1118, 1314]
#
#
#  The above results are given in terms of absolute numbers. In relative terms, the response variable showed  an increase
# of  2.5%. The 95% interval of this percentage is [10.6%, -5.5%]
#
#
#  This means that the positive effect observed during the intervention period is statistically significant and unlikely
# to be due to random fluctuations. It should be noted, however, that the question of whether this increase also bears
# substantive significance can only be answered by comparing the absolute effect 3 to the original goal of the underlying
# intervention.
#
#
# The probability of obtaining this effect by                 chance is very small (Bayesian one-sided tail-area
# probability 0.0). This means the                 causal effect can be considered statistically
# significant.
# C:\Users\joanp\AppData\Local\Temp\ipykernel_39932\4049619924.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\joanp\anaconda3\envs\causal_inference_ts\Lib\site-packages\statsmodels\tsa\statespace\representation.py:374: FutureWarning:
#
# Unknown keyword arguments: dict_keys(['alpha']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
# ===== Industria de Diseño Textil, S.A. =====
# The mean absolute percentage error in the pre period is 0.03%
#                                Average      Cumulative
# Actual                              21             196
# Predicted                           25             229
# 95% CI                        [21, 29]      [195, 263]
#
# Absolute Effect                     -3             -33
# 95% CI                         [0, -7]        [0, -67]
#
# Relative Effect                 -14.5%          -14.5%
# 95% CI                  [0.3%, -29.3%]  [0.3%, -29.3%]
#
# P-value                           0.0%
# Prob. of Causal Effect          100.0%
# None
#                                Average      Cumulative
# Actual                              21             196
# Predicted                           25             229
# 95% CI                        [21, 29]      [195, 263]
#
# Absolute Effect                     -3             -33
# 95% CI                         [0, -7]        [0, -67]
#
# Relative Effect                 -14.5%          -14.5%
# 95% CI                  [0.3%, -29.3%]  [0.3%, -29.3%]
#
# P-value                           0.0%
# Prob. of Causal Effect          100.0%
# During the post-intervention period, the response             variable had an average value of             approx. 21.
# By contrast, in  the absence of an intervention, we would have expected an average response of 25. The 95% interval of
# this counterfactual prediction is [21, 29]. Subtracting this prediction from the observed response yields an estimate of
# the causal effect the intervention had on the response variable. This effect is -3 with a 95% interval of [0, -7]. For a
# discussion of the significance of this effect, see below.
#
#
#  Summing up the individual data points during the post-intervention period (which can only sometimes be meaningfully
# interpreted), the response variable had an overall value of 196.  By contrast, had  the intervention not taken place, we
# would have expected a sum of 229. The 95% interval of this prediction is [195, 263]
#
#
#  The above results are given in terms of absolute numbers. In relative terms, the response variable showed  a decrease
# of  -14.5%. The 95% interval of this percentage is [0.3%, -29.3%]
#
#
#  This  means that the negative effect observed during the intervention period is statistically significant. If the
# experimenter had expected a positive effect, it is recommended to double-check whether anomalies in the control
# variables may have caused an overly optimistic expectation of what should have happened in the response variable in the
# absence of the intervention.
#
#
# The probability of obtaining this effect by                 chance is very small (Bayesian one-sided tail-area
# probability 0.0). This means the                 causal effect can be considered statistically
# significant.
# C:\Users\joanp\AppData\Local\Temp\ipykernel_39932\4049619924.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\joanp\anaconda3\envs\causal_inference_ts\Lib\site-packages\statsmodels\tsa\statespace\representation.py:374: FutureWarning:
#
# Unknown keyword arguments: dict_keys(['alpha']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
# ===== Hennes & Mauritz AB =====
# The mean absolute percentage error in the pre period is 0.05%
#                                 Average       Cumulative
# Actual                                2               24
# Predicted                             2               25
# 95% CI                           [1, 3]         [17, 32]
#
# Absolute Effect                       0                0
# 95% CI                           [0, 0]          [6, -8]
#
# Relative Effect                   -3.7%            -3.7%
# 95% CI                  [26.0%, -33.4%]  [26.0%, -33.4%]
#
# P-value                            0.0%
# Prob. of Causal Effect           100.0%
# None
#                                 Average       Cumulative
# Actual                                2               24
# Predicted                             2               25
# 95% CI                           [1, 3]         [17, 32]
#
# Absolute Effect                       0                0
# 95% CI                           [0, 0]          [6, -8]
#
# Relative Effect                   -3.7%            -3.7%
# 95% CI                  [26.0%, -33.4%]  [26.0%, -33.4%]
#
# P-value                            0.0%
# Prob. of Causal Effect           100.0%
# During the post-intervention period, the response             variable had an average value of             approx. 2.
# By contrast, in  the absence of an intervention, we would have expected an average response of 2. The 95% interval of
# this counterfactual prediction is [1, 3]. Subtracting this prediction from the observed response yields an estimate of
# the causal effect the intervention had on the response variable. This effect is 0 with a 95% interval of [0, 0]. For a
# discussion of the significance of this effect, see below.
#
#
#  Summing up the individual data points during the post-intervention period (which can only sometimes be meaningfully
# interpreted), the response variable had an overall value of 24.  By contrast, had  the intervention not taken place, we
# would have expected a sum of 25. The 95% interval of this prediction is [17, 32]
#
#
#  The above results are given in terms of absolute numbers. In relative terms, the response variable showed  a decrease
# of  -3.7%. The 95% interval of this percentage is [26.0%, -33.4%]
#
#
#  This  means that the negative effect observed during the intervention period is statistically significant. If the
# experimenter had expected a positive effect, it is recommended to double-check whether anomalies in the control
# variables may have caused an overly optimistic expectation of what should have happened in the response variable in the
# absence of the intervention.
#
#
# The probability of obtaining this effect by                 chance is very small (Bayesian one-sided tail-area
# probability 0.0). This means the                 causal effect can be considered statistically
# significant.
# C:\Users\joanp\AppData\Local\Temp\ipykernel_39932\4049619924.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\joanp\anaconda3\envs\causal_inference_ts\Lib\site-packages\statsmodels\tsa\statespace\representation.py:374: FutureWarning:
#
# Unknown keyword arguments: dict_keys(['alpha']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
# ===== LVMH Moët Hennessy Louis Vuitton S.E. =====
# The mean absolute percentage error in the pre period is 0.03%
#                               Average     Cumulative
# Actual                            368           3316
# Predicted                         327           2946
# 95% CI                     [290, 363]   [2617, 3274]
#
# Absolute Effect                    41            370
# 95% CI                        [77, 4]      [698, 42]
#
# Relative Effect                 12.6%          12.6%
# 95% CI                  [23.7%, 1.4%]  [23.7%, 1.4%]
#
# P-value                          0.0%
# Prob. of Causal Effect         100.0%
# None
#                               Average     Cumulative
# Actual                            368           3316
# Predicted                         327           2946
# 95% CI                     [290, 363]   [2617, 3274]
#
# Absolute Effect                    41            370
# 95% CI                        [77, 4]      [698, 42]
#
# Relative Effect                 12.6%          12.6%
# 95% CI                  [23.7%, 1.4%]  [23.7%, 1.4%]
#
# P-value                          0.0%
# Prob. of Causal Effect         100.0%
# During the post-intervention period, the response             variable had an average value of             approx. 368.
# By contrast, in  the absence of an intervention, we would have expected an average response of 327. The 95% interval of
# this counterfactual prediction is [290, 363]. Subtracting this prediction from the observed response yields an estimate
# of the causal effect the intervention had on the response variable. This effect is 41 with a 95% interval of [77, 4].
# For a discussion of the significance of this effect, see below.
#
#
#  Summing up the individual data points during the post-intervention period (which can only sometimes be meaningfully
# interpreted), the response variable had an overall value of 3316.  By contrast, had  the intervention not taken place,
# we would have expected a sum of 2946. The 95% interval of this prediction is [2617, 3274]
#
#
#  The above results are given in terms of absolute numbers. In relative terms, the response variable showed  an increase
# of  12.6%. The 95% interval of this percentage is [23.7%, 1.4%]
#
#
#  This means that the positive effect observed during the intervention period is statistically significant and unlikely
# to be due to random fluctuations. It should be noted, however, that the question of whether this increase also bears
# substantive significance can only be answered by comparing the absolute effect 41 to the original goal of the underlying
# intervention.
#
#
# The probability of obtaining this effect by                 chance is very small (Bayesian one-sided tail-area
# probability 0.0). This means the                 causal effect can be considered statistically
# significant.
# C:\Users\joanp\AppData\Local\Temp\ipykernel_39932\4049619924.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\joanp\anaconda3\envs\causal_inference_ts\Lib\site-packages\statsmodels\tsa\statespace\representation.py:374: FutureWarning:
#
# Unknown keyword arguments: dict_keys(['alpha']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
# ===== Fast Retailing Co., Ltd. =====
# The mean absolute percentage error in the pre period is 0.06%
#                                Average       Cumulative
# Actual                           19835           178516
# Predicted                        12310           110796
# 95% CI                   [8491, 16129]  [76425, 145167]
#
# Absolute Effect                   7524            67719
# 95% CI                   [11343, 3705]  [102090, 33348]
#
# Relative Effect                  61.1%            61.1%
# 95% CI                  [92.1%, 30.1%]   [92.1%, 30.1%]
#
# P-value                           0.0%
# Prob. of Causal Effect          100.0%
# None
#                                Average       Cumulative
# Actual                           19835           178516
# Predicted                        12310           110796
# 95% CI                   [8491, 16129]  [76425, 145167]
#
# Absolute Effect                   7524            67719
# 95% CI                   [11343, 3705]  [102090, 33348]
#
# Relative Effect                  61.1%            61.1%
# 95% CI                  [92.1%, 30.1%]   [92.1%, 30.1%]
#
# P-value                           0.0%
# Prob. of Causal Effect          100.0%
# During the post-intervention period, the response             variable had an average value of             approx.
# 19835.  By contrast, in  the absence of an intervention, we would have expected an average response of 12310. The 95%
# interval of this counterfactual prediction is [8491, 16129]. Subtracting this prediction from the observed response
# yields an estimate of the causal effect the intervention had on the response variable. This effect is 7524 with a 95%
# interval of [11343, 3705]. For a discussion of the significance of this effect, see below.
#
#
#  Summing up the individual data points during the post-intervention period (which can only sometimes be meaningfully
# interpreted), the response variable had an overall value of 178516.  By contrast, had  the intervention not taken place,
# we would have expected a sum of 110796. The 95% interval of this prediction is [76425, 145167]
#
#
#  The above results are given in terms of absolute numbers. In relative terms, the response variable showed  an increase
# of  61.1%. The 95% interval of this percentage is [92.1%, 30.1%]
#
#
#  This means that the positive effect observed during the intervention period is statistically significant and unlikely
# to be due to random fluctuations. It should be noted, however, that the question of whether this increase also bears
# substantive significance can only be answered by comparing the absolute effect 7524 to the original goal of the
# underlying intervention.
#
#
# The probability of obtaining this effect by                 chance is very small (Bayesian one-sided tail-area
# probability 0.0). This means the                 causal effect can be considered statistically
# significant.
# C:\Users\joanp\AppData\Local\Temp\ipykernel_39932\4049619924.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\joanp\anaconda3\envs\causal_inference_ts\Lib\site-packages\statsmodels\tsa\statespace\representation.py:374: FutureWarning:
#
# Unknown keyword arguments: dict_keys(['alpha']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.

# %%
covid_causal_impact(consumer_staples)
# Out:
# ===== The Coca-Cola Company (KO) =====
# The mean absolute percentage error in the pre period is 0.03%
#                                 Average       Cumulative
# Actual                               43              387
# Predicted                            49              441
# 95% CI                         [44, 53]       [401, 481]
#
# Absolute Effect                      -5              -53
# 95% CI                        [-1, -10]       [-13, -93]
#
# Relative Effect                  -12.2%           -12.2%
# 95% CI                  [-3.1%, -21.3%]  [-3.1%, -21.3%]
#
# P-value                            0.0%
# Prob. of Causal Effect           100.0%
# None
#                                 Average       Cumulative
# Actual                               43              387
# Predicted                            49              441
# 95% CI                         [44, 53]       [401, 481]
#
# Absolute Effect                      -5              -53
# 95% CI                        [-1, -10]       [-13, -93]
#
# Relative Effect                  -12.2%           -12.2%
# 95% CI                  [-3.1%, -21.3%]  [-3.1%, -21.3%]
#
# P-value                            0.0%
# Prob. of Causal Effect           100.0%
# During the post-intervention period, the response             variable had an average value of             approx. 43.
# By contrast, in  the absence of an intervention, we would have expected an average response of 49. The 95% interval of
# this counterfactual prediction is [44, 53]. Subtracting this prediction from the observed response yields an estimate of
# the causal effect the intervention had on the response variable. This effect is -5 with a 95% interval of [-1, -10]. For
# a discussion of the significance of this effect, see below.
#
#
#  Summing up the individual data points during the post-intervention period (which can only sometimes be meaningfully
# interpreted), the response variable had an overall value of 387.  By contrast, had  the intervention not taken place, we
# would have expected a sum of 441. The 95% interval of this prediction is [401, 481]
#
#
#  The above results are given in terms of absolute numbers. In relative terms, the response variable showed  a decrease
# of  -12.2%. The 95% interval of this percentage is [-3.1%, -21.3%]
#
#
#  This  means that the negative effect observed during the intervention period is statistically significant. If the
# experimenter had expected a positive effect, it is recommended to double-check whether anomalies in the control
# variables may have caused an overly optimistic expectation of what should have happened in the response variable in the
# absence of the intervention.
#
#
# The probability of obtaining this effect by                 chance is very small (Bayesian one-sided tail-area
# probability 0.0). This means the                 causal effect can be considered statistically
# significant.
# C:\Users\joanp\AppData\Local\Temp\ipykernel_39932\4049619924.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\joanp\anaconda3\envs\causal_inference_ts\Lib\site-packages\statsmodels\tsa\statespace\representation.py:374: FutureWarning:
#
# Unknown keyword arguments: dict_keys(['alpha']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
# ===== Colgate-Palmolive Company (CL): =====
# The mean absolute percentage error in the pre period is 0.02%
#                                Average      Cumulative
# Actual                              68             620
# Predicted                           61             551
# 95% CI                        [53, 68]      [483, 620]
#
# Absolute Effect                      7              68
# 95% CI                         [15, 0]        [137, 0]
#
# Relative Effect                  12.4%           12.4%
# 95% CI                  [24.9%, -0.0%]  [24.9%, -0.0%]
#
# P-value                           0.0%
# Prob. of Causal Effect          100.0%
# None
#                                Average      Cumulative
# Actual                              68             620
# Predicted                           61             551
# 95% CI                        [53, 68]      [483, 620]
#
# Absolute Effect                      7              68
# 95% CI                         [15, 0]        [137, 0]
#
# Relative Effect                  12.4%           12.4%
# 95% CI                  [24.9%, -0.0%]  [24.9%, -0.0%]
#
# P-value                           0.0%
# Prob. of Causal Effect          100.0%
# During the post-intervention period, the response             variable had an average value of             approx. 68.
# By contrast, in  the absence of an intervention, we would have expected an average response of 61. The 95% interval of
# this counterfactual prediction is [53, 68]. Subtracting this prediction from the observed response yields an estimate of
# the causal effect the intervention had on the response variable. This effect is 7 with a 95% interval of [15, 0]. For a
# discussion of the significance of this effect, see below.
#
#
#  Summing up the individual data points during the post-intervention period (which can only sometimes be meaningfully
# interpreted), the response variable had an overall value of 620.  By contrast, had  the intervention not taken place, we
# would have expected a sum of 551. The 95% interval of this prediction is [483, 620]
#
#
#  The above results are given in terms of absolute numbers. In relative terms, the response variable showed  an increase
# of  12.4%. The 95% interval of this percentage is [24.9%, -0.0%]
#
#
#  This means that the positive effect observed during the intervention period is statistically significant and unlikely
# to be due to random fluctuations. It should be noted, however, that the question of whether this increase also bears
# substantive significance can only be answered by comparing the absolute effect 7 to the original goal of the underlying
# intervention.
#
#
# The probability of obtaining this effect by                 chance is very small (Bayesian one-sided tail-area
# probability 0.0). This means the                 causal effect can be considered statistically
# significant.
# C:\Users\joanp\AppData\Local\Temp\ipykernel_39932\4049619924.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\joanp\anaconda3\envs\causal_inference_ts\Lib\site-packages\statsmodels\tsa\statespace\representation.py:374: FutureWarning:
#
# Unknown keyword arguments: dict_keys(['alpha']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
# ===== Kimberly-Clark Corporation (KMB) =====
# The mean absolute percentage error in the pre period is 0.02%
#                               Average     Cumulative
# Actual                            126           1134
# Predicted                         111           1002
# 95% CI                      [98, 123]    [890, 1114]
#
# Absolute Effect                    14            131
# 95% CI                        [27, 2]      [243, 19]
#
# Relative Effect                 13.1%          13.1%
# 95% CI                  [24.3%, 2.0%]  [24.3%, 2.0%]
#
# P-value                          0.0%
# Prob. of Causal Effect         100.0%
# None
#                               Average     Cumulative
# Actual                            126           1134
# Predicted                         111           1002
# 95% CI                      [98, 123]    [890, 1114]
#
# Absolute Effect                    14            131
# 95% CI                        [27, 2]      [243, 19]
#
# Relative Effect                 13.1%          13.1%
# 95% CI                  [24.3%, 2.0%]  [24.3%, 2.0%]
#
# P-value                          0.0%
# Prob. of Causal Effect         100.0%
# During the post-intervention period, the response             variable had an average value of             approx. 126.
# By contrast, in  the absence of an intervention, we would have expected an average response of 111. The 95% interval of
# this counterfactual prediction is [98, 123]. Subtracting this prediction from the observed response yields an estimate
# of the causal effect the intervention had on the response variable. This effect is 14 with a 95% interval of [27, 2].
# For a discussion of the significance of this effect, see below.
#
#
#  Summing up the individual data points during the post-intervention period (which can only sometimes be meaningfully
# interpreted), the response variable had an overall value of 1134.  By contrast, had  the intervention not taken place,
# we would have expected a sum of 1002. The 95% interval of this prediction is [890, 1114]
#
#
#  The above results are given in terms of absolute numbers. In relative terms, the response variable showed  an increase
# of  13.1%. The 95% interval of this percentage is [24.3%, 2.0%]
#
#
#  This means that the positive effect observed during the intervention period is statistically significant and unlikely
# to be due to random fluctuations. It should be noted, however, that the question of whether this increase also bears
# substantive significance can only be answered by comparing the absolute effect 14 to the original goal of the underlying
# intervention.
#
#
# The probability of obtaining this effect by                 chance is very small (Bayesian one-sided tail-area
# probability 0.0). This means the                 causal effect can be considered statistically
# significant.
# C:\Users\joanp\AppData\Local\Temp\ipykernel_39932\4049619924.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\joanp\anaconda3\envs\causal_inference_ts\Lib\site-packages\statsmodels\tsa\statespace\representation.py:374: FutureWarning:
#
# Unknown keyword arguments: dict_keys(['alpha']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
# ===== Unilever (UL) =====
# The mean absolute percentage error in the pre period is 0.03%
#                               Average     Cumulative
# Actual                             50            451
# Predicted                          44            397
# 95% CI                       [39, 49]     [351, 442]
#
# Absolute Effect                     5             53
# 95% CI                        [11, 0]        [99, 8]
#
# Relative Effect                 13.5%          13.5%
# 95% CI                  [25.0%, 2.1%]  [25.0%, 2.1%]
#
# P-value                          0.0%
# Prob. of Causal Effect         100.0%
# None
#                               Average     Cumulative
# Actual                             50            451
# Predicted                          44            397
# 95% CI                       [39, 49]     [351, 442]
#
# Absolute Effect                     5             53
# 95% CI                        [11, 0]        [99, 8]
#
# Relative Effect                 13.5%          13.5%
# 95% CI                  [25.0%, 2.1%]  [25.0%, 2.1%]
#
# P-value                          0.0%
# Prob. of Causal Effect         100.0%
# During the post-intervention period, the response             variable had an average value of             approx. 50.
# By contrast, in  the absence of an intervention, we would have expected an average response of 44. The 95% interval of
# this counterfactual prediction is [39, 49]. Subtracting this prediction from the observed response yields an estimate of
# the causal effect the intervention had on the response variable. This effect is 5 with a 95% interval of [11, 0]. For a
# discussion of the significance of this effect, see below.
#
#
#  Summing up the individual data points during the post-intervention period (which can only sometimes be meaningfully
# interpreted), the response variable had an overall value of 451.  By contrast, had  the intervention not taken place, we
# would have expected a sum of 397. The 95% interval of this prediction is [351, 442]
#
#
#  The above results are given in terms of absolute numbers. In relative terms, the response variable showed  an increase
# of  13.5%. The 95% interval of this percentage is [25.0%, 2.1%]
#
#
#  This means that the positive effect observed during the intervention period is statistically significant and unlikely
# to be due to random fluctuations. It should be noted, however, that the question of whether this increase also bears
# substantive significance can only be answered by comparing the absolute effect 5 to the original goal of the underlying
# intervention.
#
#
# The probability of obtaining this effect by                 chance is very small (Bayesian one-sided tail-area
# probability 0.0). This means the                 causal effect can be considered statistically
# significant.
# C:\Users\joanp\AppData\Local\Temp\ipykernel_39932\4049619924.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\joanp\anaconda3\envs\causal_inference_ts\Lib\site-packages\statsmodels\tsa\statespace\representation.py:374: FutureWarning:
#
# Unknown keyword arguments: dict_keys(['alpha']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
